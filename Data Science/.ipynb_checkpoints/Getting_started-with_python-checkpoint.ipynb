# %%
print('welcome to python community')
# Out:
# welcome to python community

# %%
print("This is second program")
# Out:
# This is second program

# %%
print('in next video we will learn about variables, constant and operators')
# Out:
# in next video we will learn about variables, constant and operators
